# %% [markdown]
# <a href="https://colab.research.google.com/github/viktorijaivanova9-star/01-nedela-python-setup/blob/main/programmesana1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print("Fill in the table.")
# Out:
# Fill in the table.

# %%
# Sviestmaizes pagatavošana

# %%
maize_grauzdeta = input("Vai maize ir grauzdēta? (jā/nē): ")
if maize_grauzdeta.lower() != "jā":
  print("Grauzdē maizi...")
# Out:
# Vai maize ir grauzdēta? (jā/nē): jā

# %%
print("Paņem sviestu")
# Out:
# Paņem sviestu

# %%
print("Uzsmērē sviestu uz maizes")
# Out:
# Uzsmērē sviestu uz maizes

# %%
piedevas = input("Vai pievienot piedevas? (jā/nē): ")
if piedevas.lower() == "jā":
  print("Pievieno piedevas")
# Out:
# Vai pievienot piedevas? (jā/nē): jā
# Pievieno piedevas
